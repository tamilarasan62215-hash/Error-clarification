# %%
import pandas as pd

# %%
from Univariate import univariate  # quantative and qualitative in class

# %%
dataset=pd.read_csv("Placement.csv")
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
quan,qual=univariate.quanQual(dataset)
# Out:
# quan
# qual
# quan
# qual
# quan
# qual
# qual
# quan
# qual
# qual
# quan
# qual
# quan
# qual
# quan

# %%
quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
qual
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status']

# %% [markdown]
# # Central tendency

# %%
# like title (Head Line) Run >cell type>markdown creat the titel

# %%
dataset.describe() # show an some little data using for know information for dataset
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %% [markdown]
# # how to creat a table colum for [mean,meadian,mode]

# %%
dataset["ssc_p"].mean()    # average for ssc_p this data
# Out:
# np.float64(67.30339534883721)

# %%
dataset["ssc_p"].median()   # center or (medile) value in ssc_p this data
# Out:
# np.float64(67.0)

# %%
dataset["ssc_p"].mode()   # repeated value in ssc_p this data
# Out:
# 0    62.0
# Name: ssc_p, dtype: float64

# %%
dataset["ssc_p"].mode()[0] # [0] avoid the index and dtype only for mode
# Out:
# np.float64(62.0)

# %%
descriptive=pd.DataFrame()     # create a table colum for data
descriptive
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
descriptive=pd.DataFrame(index=["mean","median","mode"])  # given index for table data
descriptive
# Out:
# Empty DataFrame
# Columns: []
# Index: [mean, median, mode]

# %%
descriptive=pd.DataFrame(index=["mean","median","mode"],columns=quan) # index with quan column
descriptive
# Out:
#        sl_no ssc_p hsc_p degree_p etest_p mba_p salary
# mean     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# median   NaN   NaN   NaN      NaN     NaN   NaN    NaN
# mode     NaN   NaN   NaN      NaN     NaN   NaN    NaN

# %%
descriptive["hsc_p"]["median"]=[0] # hsc_p > (colum) in median > (row) give an value add value that cell [0]
# Out:
# /var/folders/pr/z6v4w6ps3634swfd3h94s0hc0000gn/T/ipykernel_1762/3580280845.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...

# %%
descriptive
# Out:
#        sl_no ssc_p hsc_p degree_p etest_p mba_p salary
# mean     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# median   NaN   NaN   [0]      NaN     NaN   NaN    NaN
# mode     NaN   NaN   NaN      NaN     NaN   NaN    NaN

# %%
descriptive=pd.DataFrame(index=["mean","median","mode"],columns=quan)
for columnName in quan:
    descriptive[columnName]["mean"]=dataset[columnName].mean()    # give mean(row) value to table

# %%
descriptive

# %%
descriptive=pd.DataFrame(index=["mean","median","mode"],columns=quan)
for columnName in quan:
    descriptive[columnName]["mean"]=dataset[columnName].mean()
    descriptive[columnName]["median"]=dataset[columnName].median()  # median value

# %%
descriptive

# %%
descriptive=pd.DataFrame(index=["mean","median","mode"],columns=quan)
for columnName in quan:
   descriptive[columnName]["mode"]=dataset[columnName].mode() #repeated

# %%
descriptive

# %%
descriptive=pd.DataFrame(index=["mean","median","mode"],columns=quan)
for columnName in quan:
    descriptive[columnName]["mean"]=dataset[columnName].mean()
    descriptive[columnName]["median"]=dataset[columnName].median()
    descriptive[columnName]["mode"]=dataset[columnName].mode()[0]
# Out:
# /var/folders/pr/z6v4w6ps3634swfd3h94s0hc0000gn/T/ipykernel_1762/3914662955.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive[columnName]["mean"]=dataset[columnName].mean()
# ...

# %%
descriptive
# Out:
#         sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# mean    108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# median  108.0       67.0       65.0       66.0       71.0       62.0
# mode        1       62.0       63.0       65.0       60.0       56.7
#
#                salary
# mean    288655.405405
# median       265000.0
# mode         300000.0

# %% [markdown]
# # percentile (range of value)

# %%
import numpy as np    # numpy lib is used for numerical calculation

# %%
np.percentile (dataset["ssc_p"],99) # percentile shows the range value (99% of ssc_p mark value is 87 )
# Out:
# np.float64(87.0)

# %%
descriptive=pd.DataFrame(index=["mean","median","mode","Q1:25%","Q2:50%","Q3:75%","99%","Q4:100%",],columns=quan)
for columnName in quan:
    descriptive[columnName]["mean"]=dataset[columnName].mean()
    descriptive[columnName]["median"]=dataset[columnName].median()
    descriptive[columnName]["mode"]=dataset[columnName].mode()[0]
    descriptive[columnName]["Q1:25%"]=np.percentile(dataset[columnName],25) # not finde the Salary (NaN present)
# Out:
# /var/folders/pr/z6v4w6ps3634swfd3h94s0hc0000gn/T/ipykernel_1762/1514248291.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive[columnName]["mean"]=dataset[columnName].mean()
# ...

# %%
descriptive
# Out:
#          sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# mean     108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# median   108.0       67.0       65.0       66.0       71.0       62.0
# mode         1       62.0       63.0       65.0       60.0       56.7
# Q1:25%    54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%     NaN        NaN        NaN        NaN        NaN        NaN
# Q3:75%     NaN        NaN        NaN        NaN        NaN        NaN
# 99%        NaN        NaN        NaN        NaN        NaN        NaN
# Q4:100%    NaN        NaN        NaN        NaN        NaN        NaN
#
#                 salary
# mean     288655.405405
# median        265000.0
# mode          300000.0
# Q1:25%             NaN
# Q2:50%             NaN
# Q3:75%             NaN
# 99%                NaN
# Q4:100%            NaN

# %%
descriptive=pd.DataFrame(index=["mean","median","mode","Q1:25%","Q2:50%","Q3:75%","99%","Q4:100%",],columns=quan)
for columnName in quan:
    descriptive[columnName]["mean"]=dataset[columnName].mean()
    descriptive[columnName]["median"]=dataset[columnName].median()
    descriptive[columnName]["mode"]=dataset[columnName].mode()[0]
    descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"] # Finde the Salary in dataset(describe)table column in 25% row(value)

# %%
descriptive

# %%
descriptive=pd.DataFrame(index=["mean","median","mode","Q1:25%","Q2:50%","Q3:75%","99%","Q4:100%",],columns=quan)
for columnName in quan:
    descriptive[columnName]["mean"]=dataset[columnName].mean()
    descriptive[columnName]["median"]=dataset[columnName].median()
    descriptive[columnName]["mode"]=dataset[columnName].mode()[0]
    descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"]
    descriptive[columnName]["Q2:50%"]=dataset.describe()[columnName]["50%"]
    descriptive[columnName]["Q3:75%"]=dataset.describe()[columnName]["75%"]
    descriptive[columnName]["99%"]=np.percentile(dataset[columnName],99)       # 99% salary valu not in describe so using percentile 
    descriptive[columnName]["Q4:100%"]=dataset.describe()[columnName]["max"]      # in ["max"] column
# Out:
# /var/folders/pr/z6v4w6ps3634swfd3h94s0hc0000gn/T/ipykernel_1762/1500720081.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive[columnName]["mean"]=dataset[columnName].mean()
# ...

# %%
descriptive
# Out:
#           sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# mean      108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# median    108.0       67.0       65.0       66.0       71.0       62.0
# mode          1       62.0       63.0       65.0       60.0       56.7
# Q1:25%     54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%    108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%    161.5       75.7       73.0       72.0       83.5     66.255
# 99%      212.86       87.0      91.86      83.86       97.0    76.1142
# Q4:100%   215.0       89.4       97.7       91.0       98.0      77.89
#
#                 salary
# mean     288655.405405
# median        265000.0
# mode          300000.0
# Q1:25%        240000.0
# Q2:50%        265000.0
# Q3:75%        300000.0
# 99%                NaN
# Q4:100%       940000.0

# %% [markdown]
# # IQR(inter qurtile range) advance percentile application

# %%
descriptive=pd.DataFrame(index=["mean","median","mode","Q1:25%","Q2:50%","Q3:75%","99%","Q4:100%","IQR","1.5rule","lesser","greater","min","max"],columns=quan)
for columnName in quan:
    descriptive[columnName]["mean"]=dataset[columnName].mean()
    descriptive[columnName]["median"]=dataset[columnName].median()
    descriptive[columnName]["mode"]=dataset[columnName].mode()[0]
    descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"]
    descriptive[columnName]["Q2:50%"]=dataset.describe()[columnName]["50%"]
    descriptive[columnName]["Q3:75%"]=dataset.describe()[columnName]["75%"]
    descriptive[columnName]["99%"]=np.percentile(dataset[columnName],99)       # 99% salary valu not in describe so using percentile 
    descriptive[columnName]["Q4:100%"]=dataset.describe()[columnName]["max"]      # in ["max"] column
    descriptive[columnName]["IQR"]=descriptive[columnName]["Q3:75%"]-descriptive[columnName]["Q1:25%"]   #(Q3 percentile - Q1 percentile)
    descriptive[columnName]["1.5rule"]=1.5*descriptive[columnName]["IQR"]  #(1.5 * IQR value)
    descriptive[columnName]["lesser"]=descriptive[columnName]["Q1:25%"]-descriptive[columnName]["1.5rule"]  #(Q1-IQR)
    descriptive[columnName]["greater"]=descriptive[columnName]["Q3:75%"]+descriptive[columnName]["1.5rule"] #(Q3+IQR)
    descriptive[columnName]["min"]=dataset[columnName].min() # dataset minimum value
    descriptive[columnName]["max"]=dataset[columnName].max() # dataset maxmium value
# Out:
# /var/folders/pr/z6v4w6ps3634swfd3h94s0hc0000gn/T/ipykernel_1762/2474030972.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive[columnName]["mean"]=dataset[columnName].mean()
# ...

# %%
descriptive
# Out:
#           sl_no ssc_p hsc_p degree_p    etest_p   mba_p    salary
# mean      108.0  45.5  85.1     83.0  72.100558  74.565  360000.0
# median    108.0  45.5  85.1     83.0       71.0  74.565  360000.0
# mode          1  45.5  85.1     83.0       60.0  74.565  360000.0
# Q1:25%     54.5  45.5  85.1     83.0       60.0  74.565  360000.0
# Q2:50%    108.0  45.5  85.1     83.0       71.0  74.565  360000.0
# Q3:75%    161.5  45.5  85.1     83.0       83.5  74.565  360000.0
# 99%      212.86  45.5  85.1     83.0       97.0  74.565       NaN
# Q4:100%   215.0  45.5  85.1     83.0       98.0  74.565  360000.0
# IQR       107.0   0.0   0.0      0.0       23.5     0.0       0.0
# 1.5rule   160.5   0.0   0.0      0.0      35.25     0.0       0.0
# lesser   -106.0  45.5  85.1     83.0      24.75  74.565  360000.0
# greater   322.0  45.5  85.1     83.0     118.75  74.565  360000.0
# min           1  45.5  85.1     83.0       50.0  74.565  360000.0
# ...

# %%
descriptive["hsc_p"]["min"]<=descriptive["hsc_p"]["lesser"]  #37.0 < 48.8 True but concept min value small than lesser value
# Out:
# np.True_

# %%
quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %% [markdown]
# # Finde outlier in quan datas

# %%
Lesser=[]
Greater=[]
for columnName in quan:
    if descriptive[columnName]["min"]>=descriptive[columnName]["lesser"]: #(min value samle than lesser value add ColumName in lesser)
        Lesser.append(columnName)
    if descriptive [columnName]["max"]<=descriptive[columnName]["greater"]:  #(max value hier than greater value add ColumName in Greater)
        Greater.append(columnName)

# %%
Lesser
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
Greater
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %% [markdown]
# # Replace the outlier value

# %%
for columnName in Lesser:
    dataset[columnName][dataset[columnName]>=descriptive[columnName]["lesser"]]=descriptive[columnName]["lesser"]
for columnName in Greater:
    dataset[columnName][dataset[columnName]<=descriptive[columnName]["greater"]]=descriptive[columnName]["greater"]
# Out:
# /var/folders/pr/z6v4w6ps3634swfd3h94s0hc0000gn/T/ipykernel_1762/438836169.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...

# %%
descriptive
# Out:
#           sl_no ssc_p hsc_p degree_p    etest_p   mba_p    salary
# mean      108.0  45.5  85.1     83.0  72.100558  74.565  360000.0
# median    108.0  45.5  85.1     83.0       71.0  74.565  360000.0
# mode          1  45.5  85.1     83.0       60.0  74.565  360000.0
# Q1:25%     54.5  45.5  85.1     83.0       60.0  74.565  360000.0
# Q2:50%    108.0  45.5  85.1     83.0       71.0  74.565  360000.0
# Q3:75%    161.5  45.5  85.1     83.0       83.5  74.565  360000.0
# 99%      212.86  45.5  85.1     83.0       97.0  74.565       NaN
# Q4:100%   215.0  45.5  85.1     83.0       98.0  74.565  360000.0
# IQR       107.0   0.0   0.0      0.0       23.5     0.0       0.0
# 1.5rule   160.5   0.0   0.0      0.0      35.25     0.0       0.0
# lesser   -106.0  45.5  85.1     83.0      24.75  74.565  360000.0
# greater   322.0  45.5  85.1     83.0     118.75  74.565  360000.0
# min           1  45.5  85.1     83.0       50.0  74.565  360000.0
# ...

# %%
LLesser=[]
GGreater=[]
for columnName in quan:
    if descriptive[columnName]["min"]<descriptive[columnName]["lesser"]: #(min value samle than lesser value add ColumName in lesser)
        LLesser.append(columnName)
    if descriptive [columnName]["max"]>descriptive[columnName]["greater"]:  #(max value hier than greater value add ColumName in Greater)
        GGreater.append(columnName)

# %%
LLesser
# Out:
# []

# %%
GGreater
# Out:
# []

# %% [markdown]
# ###
