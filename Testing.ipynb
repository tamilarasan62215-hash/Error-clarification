# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv("Placement.csv")

# %%
from Univariate import univariate

# %%
quan,qual=univariate.quanQual(dataset)
# Out:
# quan
# qual
# quan
# qual
# quan
# qual
# qual
# quan
# qual
# qual
# quan
# qual
# quan
# qual
# quan

# %%
quan

# %%
qual

# %%
dataset.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %%
def univariate(dataset,quan):
    descriptive=pd.DataFrame(index=["mean","median","mode","Q1:25%","Q2:50%","Q3:75%","99%","Q4:100%","IQR","1.5rule","lesser","greater","min","max"],columns=quan)
    for columnName in quan:
        descriptive[columnName]["mean"]=dataset[columnName].mean()
        descriptive[columnName]["median"]=dataset[columnName].median()
        descriptive[columnName]["mode"]=dataset[columnName].mode()[0]
        descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"]
        descriptive[columnName]["Q2:50%"]=dataset.describe()[columnName]["50%"]
        descriptive[columnName]["Q3:75%"]=dataset.describe()[columnName]["75%"]
        descriptive[columnName]["99%"]=np.percentile(dataset[columnName],99)       # 99% salary valu not in describe so using percentile 
        descriptive[columnName]["Q4:100%"]=dataset.describe()[columnName]["max"]      # in ["max"] column
        descriptive[columnName]["IQR"]=descriptive[columnName]["Q3:75%"]-descriptive[columnName]["Q1:25%"]   #(Q3 percentile - Q1 percentile)
        descriptive[columnName]["1.5rule"]=1.5*descriptive[columnName]["IQR"]  #(1.5 * IQR value)
        descriptive[columnName]["lesser"]=descriptive[columnName]["Q1:25%"]-descriptive[columnName]["1.5rule"]  #(Q1-1.5rule)
        descriptive[columnName]["greater"]=descriptive[columnName]["Q3:75%"]+descriptive[columnName]["1.5rule"] #(Q3+1.5rule)
        descriptive[columnName]["min"]=dataset[columnName].min() # dataset minimum value
        descriptive[columnName]["max"]=dataset[columnName].max() # dataset maxmium value
    return descriptive

# %%
univariate(dataset,quan)
# Out:
# /var/folders/pr/z6v4w6ps3634swfd3h94s0hc0000gn/T/ipykernel_3713/2626974415.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive[columnName]["mean"]=dataset[columnName].mean()
# ...

# %%
def outlier_columnN(dataset,quan,descriptive):
    Lesser=[]
    Greater=[]
    for columnName in quan:
        if descriptive[columnName]["lesser"]>descriptive[columnName]["min"]:
            Lesser.append(columnName)
        if descriptive[columnName]["greater"]<descriptive[columnName]["max"]:
            Greater.append(columnName)
    return (Lesser,Greater)

# %%
outlier_columnN(dataset,quan,descriptive)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 outlier_columnN(dataset,quan,descriptive)
#
# NameError: name 'descriptive' is not defined

# %%
Lesser=[]
Greater=[]
for columnName in quan:
    if descriptive[columnName]["min"]<descriptive[columnName]["lesser"]:
        Lesser.append(columnName)
    if descriptive[columnName]["max"]>descriptive[columnName]["greater"]:
        Greater.append(columnName)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       2 Greater=[]
#       3 for columnName in quan:
# ----> 4     if descriptive[columnName]["min"]<descriptive[columnName]["lesser"]:
#       5         Lesser.append(columnName)
#       6     if descriptive[columnName]["max"]>descriptive[columnName]["greater"]:
#
# NameError: name 'descriptive' is not defined

# %%
Lesser

# %%
Greater

# %%
for columnName in Lesser:
    dataset[columnName][dataset[columnName]<descriptive[columnName]["lesser"]]=descriptive[columnName]["lesser"]
for columnName in Greater:
    dataset[columnName][dataset[columnName]>descriptive[columnName]["greater"]]=descriptive[columnName]["greater"]

# %%
descriptive=pd.DataFrame(index=["mean","median","mode","Q1:25%","Q2:50%","Q3:75%","99%","Q4:100%","IQR","1.5rule","lesser","greater","min","max"],columns=quan)
for columnName in quan:
    descriptive[columnName]["mean"]=dataset[columnName].mean()
    descriptive[columnName]["median"]=dataset[columnName].median()
    descriptive[columnName]["mode"]=dataset[columnName].mode()[0]
    descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"]
    descriptive[columnName]["Q2:50%"]=dataset.describe()[columnName]["50%"]
    descriptive[columnName]["Q3:75%"]=dataset.describe()[columnName]["75%"]
    descriptive[columnName]["99%"]=np.percentile(dataset[columnName],99)       # 99% salary valu not in describe so using percentile 
    descriptive[columnName]["Q4:100%"]=dataset.describe()[columnName]["max"]      # in ["max"] column
    descriptive[columnName]["IQR"]=descriptive[columnName]["Q3:75%"]-descriptive[columnName]["Q1:25%"]   #(Q3 percentile - Q1 percentile)
    descriptive[columnName]["1.5rule"]=1.5*descriptive[columnName]["IQR"]  #(1.5 * IQR value)
    descriptive[columnName]["lesser"]=descriptive[columnName]["Q1:25%"]-descriptive[columnName]["1.5rule"]  #(Q1-1.5rule)
    descriptive[columnName]["greater"]=descriptive[columnName]["Q3:75%"]+descriptive[columnName]["1.5rule"] #(Q3+1.5rule)
    descriptive[columnName]["min"]=dataset[columnName].min() # dataset minimum value
    descriptive[columnName]["max"]=dataset[columnName].max() # dataset maxmium value

# %%
descriptive

# %%
replace_Lesser=[]
replace_Greater=[]
for columnName in quan:
    if descriptive[columnName]["min"]<descriptive[columnName]["lesser"]:
        replace_Lesser.append(columnName)
    if descriptive[columnName]["greater"]<descriptive[columnName]["max"]:
        replace_Greater.append(columnName)

# %%
replace_Lesser

# %%
replace_Greater

# %% [markdown]
# # Frequency(reputed unick value count)

# %%
dataset["ssc_p"].value_counts() # unique values and no.of repetated value(frequency)

# %%
dataset["ssc_p"].value_counts().index  #only show an index(unique values)

# %%
dataset["ssc_p"].value_counts().values  #only show an frequency value(reputation) count values

# %%
dataset["ssc_p"].value_counts().sort_values # unick values with decending order (B to S)

# %%
dataset["ssc_p"].value_counts().sort_index  #decending order for frequency count values

# %%
def freqTable(columnName,dataset):
    freqTable=pd.DataFrame(columns=["Unique_values","Frequency","Relative_Frequency","cumsum"])
    freqTable["Unique_values"]=dataset[columnName].value_counts().index
    freqTable["Frequency"]=dataset[columnName].value_counts().values
    freqTable["Relative_Frequency"]=(freqTable["Frequency"]/103)
    freqTable["cumsum"]=freqTable["Relative_Frequency"].cumsum()
    return freqTable

# %%
freqTable("ssc_p",dataset) # calling the freqTable funtion
